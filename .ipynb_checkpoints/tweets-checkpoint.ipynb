# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as stopwords

# %%
df = pd.read_csv("vaccination_all_tweets.csv")

# %% [raw]
# BASIC DATA EXPLORE

# %%
df.head()
# Out:
#                     id             user_name              user_location  \
# 0  1340539111971516416            Rachel Roh  La Crescenta-Montrose, CA
# 1  1338158543359250433           Albert Fong          San Francisco, CA
# 2  1337858199140118533              eli🇱🇹🇪🇺👌                   Your Bed
# 3  1337855739918835717         Charles Adler     Vancouver, BC - Canada
# 4  1337854064604966912  Citizen News Channel                        NaN
#
#                                     user_description         user_created  \
# 0  Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 2                                     heil, hydra 🖐☺  2020-06-25 23:30:28
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2008-09-10 11:28:53
# 4  Citizen News Channel bringing you an alternati...  2020-04-23 17:58:42
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                   date                                               text  \
# 0  2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# 1  2020-12-13 16:27:13  While the world has been on the wrong side of ...
# 2  2020-12-12 20:33:45  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  2020-12-12 20:23:59  Facts are immutable, Senator, even when you're...
# 4  2020-12-12 20:17:19  Explain to me again why we need a vaccine @Bor...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1                                                NaN      Twitter Web App
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                NaN      Twitter Web App
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
#
#    retweets  favorites is_retweet
# 0       0.0        0.0      False
# 1       1.0        1.0      False
# 2       0.0        0.0      False
# 3     446.0     2129.0      False
# 4       0.0        0.0      False

# %%
df.sort_values(by="retweets").tail()
# Out:
#                         id             user_name           user_location  \
# 17543  1366306056826019840        Megh Updates 🚨  Turn on Notification 🔔
# 24268  1369208356968140802        Megh Updates 🚨  Turn on Notification 🔔
# 7126   1359520343891841034  Robert F. Kennedy Jr  Los Angles, California
# 17118  1366365003968823296     Dr. S. Jaishankar        New Delhi, India
# 31111  1371717012313886720                 あかげたん                     NaN
#
#                                         user_description         user_created  \
# 17543  Top News | Breaking | Real Time |\n🛰 Observing...  2019-03-22 18:44:11
# 24268  Top News | Breaking | Real Time |\n🛰 Observing...  2019-03-22 18:44:11
# 7126   Robert F. Kennedy, Jr. is founder + chairman o...  2011-07-18 16:22:27
# 17118                 External Affairs Minister of India  2017-05-02 11:08:14
# 31111                                                NaN  2016-11-07 15:44:43
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 17543           84326           369            54384          False
# 24268           88330           363            55368          False
# 7126           224642           594              114           True
# 17118          962016             9              100           True
# 31111              54            52             4327          False
#
#                       date                                               text  \
# 17543  2021-03-01 08:35:23  Prime Minister Narendra Modi choose early morn...
# 24268  2021-03-09 08:48:05  #Covaxin 🇮🇳 , made by Hyderabad-based Bharat B...
# 7126   2021-02-10 15:11:23  New research published in Microbiology &amp; I...
# 17118  2021-03-01 12:29:37  Got my jab. For the curious, it was #Covaxin. ...
# 31111  2021-03-16 06:56:35  #Astrazaneca \n#vactine \n#SputnikV \n\nPlease...
#
#                                      hashtags               source  retweets  \
# 17543                             ['covaxin']  Twitter for Android    1980.0
# 24268                             ['Covaxin']  Twitter for Android    2095.0
# 7126                                 ['mRNA']            TweetDeck    2247.0
# 17118                             ['Covaxin']   Twitter for iPhone    2360.0
# 31111  ['Astrazaneca', 'vactine', 'SputnikV']          Twitter for       NaN
#
#        favorites is_retweet
# 17543     8153.0      False
# 24268     9458.0      False
# 7126      3090.0      False
# 17118    22815.0      False
# 31111        NaN        NaN

# %%
x = df[df["retweets"]>12000]["text"]
print(x)
# Out:
# Series([], Name: text, dtype: object)

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.8.30)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
text = "I AM VERY SAD"
sentiment_scores = analyzer.polarity_scores(text)
print(sentiment_scores)
# Out:
# {'neg': 0.531, 'neu': 0.469, 'pos': 0.0, 'compound': -0.5256}

# %%
df2 = pd.read_csv("India_aggregate.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0        date location_key  new_confirmed  new_deceased  \
# 0     7743027  2020-01-01           IN            0.0           0.0
# 1     7743028  2020-01-02           IN            0.0           0.0
# 2     7743029  2020-01-03           IN            0.0           0.0
# 3     7743030  2020-01-04           IN            0.0           0.0
# 4     7743031  2020-01-05           IN            0.0           0.0
#
#    new_recovered  new_tested  cumulative_confirmed  cumulative_deceased  \
# 0            NaN         NaN                   0.0                  0.0
# 1            NaN         NaN                   0.0                  0.0
# 2            NaN         NaN                   0.0                  0.0
# 3            NaN         NaN                   0.0                  0.0
# 4            NaN         NaN                   0.0                  0.0
#
#    cumulative_recovered  cumulative_tested
# 0                   NaN                NaN
# 1                   NaN                NaN
# 2                   NaN                NaN
# 3                   NaN                NaN
# 4                   NaN                NaN

# %%
y = df2.groupby("date")["cumulative_confirmed"].sum()

# %%
df3 = pd.DataFrame(y.reset_index())
df3["date"] = pd.to_datetime(df3["date"]).dt.date

# %%
df["date"]
# Out:
# 0        2020-12-20 06:06:44
# 1        2020-12-13 16:27:13
# 2        2020-12-12 20:33:45
# 3        2020-12-12 20:23:59
# 4        2020-12-12 20:17:19
#                 ...
# 31107    2021-03-16 07:22:34
# 31108    2021-03-16 07:15:13
# 31109    2021-03-16 07:15:04
# 31110    2021-03-16 07:14:01
# 31111    2021-03-16 06:56:35
# Name: date, Length: 31112, dtype: object

# %%
type(df["date"][0])
# Out:
# str

# %%
df["date"] =pd.to_datetime(df["date"]).dt.date

# %%
df["date"]
# Out:
# 0        2020-12-20
# 1        2020-12-13
# 2        2020-12-12
# 3        2020-12-12
# 4        2020-12-12
#             ...
# 31107    2021-03-16
# 31108    2021-03-16
# 31109    2021-03-16
# 31110    2021-03-16
# 31111    2021-03-16
# Name: date, Length: 31112, dtype: object

# %%
df4 = df[df["user_location"].str.contains("India", na=False)]

# %%
merged = pd.merge(df3,df4,on="date")

# %%
merged
# Out:
#             date  cumulative_confirmed                   id  \
# 0     2020-12-12            21915379.0  1337815730486702087
# 1     2020-12-12            21915379.0  1337773751841144833
# 2     2020-12-12            21915379.0  1337887453726826497
# 3     2020-12-12            21915379.0  1337872353536176131
# 4     2020-12-13            21969704.0  1338027516536135680
# ...          ...                   ...                  ...
# 2842  2021-03-17            26008731.0  1372065160458694656
# 2843  2021-03-17            26008731.0  1372005850420633602
# 2844  2021-03-18            26116613.0  1372406061357920258
# 2845  2021-03-20            26347790.0  1373207446231998464
# 2846  2021-03-23            26711386.0  1374233535481966593
#
#               user_name              user_location  \
# 0                  WION                      India
# 1             BOOM Live              Mumbai, India
# 2               DD News           New Delhi, India
# 3              DD India           New Delhi, India
# 4      Outlook Magazine           New Delhi, India
# ...                 ...                        ...
# 2842         Statecraft              Mumbai, India
# 2843  Devanshi Samnotra  Jammu , New Delhi, India
# 2844   IndSamachar News                      India
# 2845   Alokendra Mandal                      India
# 2846  Harsha V Chunduri             Chennai, India
#
#                                        user_description         user_created  \
# 0     #WION: World Is One | Welcome to India’s first...  2016-03-21 03:44:54
# 1     IFCN certified fact-driven journalism. India's...  2014-03-16 03:52:50
# 2     Official Twitter account of DD News, the Publi...  2013-01-18 13:04:45
# 3     Official account of DD India, English News TV ...  2016-04-08 09:24:41
# 4             The fully loaded news magazine from India  2009-03-04 12:45:00
# ...                                                 ...                  ...
# 2842  Statecraft is a digital global affairs daily t...  2016-06-06 17:09:53
# 2843  I believe in making the impossible possible be...  2019-08-06 15:07:07
# 2844  Digital News Service . IndSamachar delivers ne...  2018-04-07 00:15:10
# 2845     𝐈 𝐚𝐦 𝐚 𝐡𝐮𝐦𝐚𝐧 𝐰𝐡𝐨 𝐛𝐞𝐥𝐨𝐧𝐠𝐬 𝐭𝐨 𝐭𝐡𝐞 𝐰𝐡𝐨𝐥𝐞 𝐮𝐧𝐢𝐯𝐞𝐫𝐬𝐞  2015-05-08 15:22:59
# 2846                                                NaN  2009-10-27 16:26:50
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 0             292510            91             7531           True
# 1              64185          1183             1794           True
# 2            3085027            78             1578           True
# 3              36594           530             7160           True
# 4             228029            62              232           True
# ...              ...           ...              ...            ...
# 2842            5528           344              218          False
# 2843              98           235            30410          False
# 2844           16131             0             1536          False
# 2845               3            29               56          False
# 2846             112           316              171          False
#
#                                                    text  \
# 0     The agency also released new information for h...
# 1     The US Food and Drug Administration (FDA) has ...
# 2     #UnitedStates : The Federal Aviation Administr...
# 3     #UnitedStates : The Federal Aviation Administr...
# 4     With numbers likely to get worse over the holi...
# ...                                                 ...
# 2842  • #Portugal backs #India's bid for permanent #...
# 2843  GLAND PHARMA has partnered with Russian Direct...
# 2844  More than 4.2 million #Turkish people have rec...
# 2845  Which vaccine do you want to take?\n\nDisclaim...
# 2846  Very thankful to have gotten my first COVID va...
#
#                                                hashtags               source  \
# 0                                                   NaN            TweetDeck
# 1                                                   NaN      Twitter Web App
# 2                                      ['UnitedStates']            TweetDeck
# 3                                      ['UnitedStates']            TweetDeck
# 4                                           ['vaccine']      Twitter Web App
# ...                                                 ...                  ...
# 2842  ['Portugal', 'India', 'UNSC', 'Azerbaijan', 'T...      Twitter Web App
# 2843                                                NaN   Twitter for iPhone
# 2844                    ['Turkish', 'Covid19', 'China']  Twitter for Android
# 2845                                                NaN      Twitter Web App
# 2846                       ['Covaxin', 'BharatBiotech']   Twitter for iPhone
#
#       retweets  favorites is_retweet
# 0          0.0       18.0      False
# 1          1.0        5.0      False
# 2          4.0       21.0      False
# 3          0.0        5.0      False
# 4          0.0        0.0      False
# ...        ...        ...        ...
# 2842       1.0        5.0      False
# 2843       1.0        7.0      False
# 2844       0.0        1.0      False
# 2845       0.0        1.0      False
# 2846       0.0        1.0      False
#
# [2847 rows x 17 columns]

# %%
plt.plot(merged["cumulative_confirmed"],analyzer.polarity_scores(merged["text"])["neg"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9b0f0a565c85> in <cell line: 1>()
# ----> 1 plt.plot(merged["cumulative_confirmed"],analyzer.polarity_scores(merged["text"])["neg"])
#
# /usr/local/lib/python3.10/dist-packages/vaderSentiment/vaderSentiment.py in polarity_scores(self, text)
#     267                 continue
#     268
# --> 269             sentiments = self.sentiment_valence(valence, sentitext, item, i, sentiments)
#     270
#     271         sentiments = self._but_check(words_and_emoticons, sentiments)
#
# /usr/local/lib/python3.10/dist-packages/vaderSentiment/vaderSentiment.py in sentiment_valence(self, valence, sentitext, item, i, sentiments)
#     310                         s = s * 0.9
#     311                     valence = valence + s
# --> 312                     valence = self._negation_check(valence, words_and_emoticons, start_i, i)
#     313                     if start_i == 2:
#     314                         valence = self._special_idioms_check(valence, words_and_emoticons, i)
#
# /usr/local/lib/python3.10/dist-packages/vaderSentiment/vaderSentiment.py in _negation_check(valence, words_and_emoticons, start_i, i)
#     400     @staticmethod
#     401     def _negation_check(valence, words_and_emoticons, start_i, i):
# --> 402         words_and_emoticons_lower = [str(w).lower() for w in words_and_emoticons]
#     403         if start_i == 0:
#     404             if negated([words_and_emoticons_lower[i - (start_i + 1)]]):  # 1 word preceding lexicon word (w/o stopwords)
#
# /usr/local/lib/python3.10/dist-packages/vaderSentiment/vaderSentiment.py in <listcomp>(.0)
#     400     @staticmethod
#     401     def _negation_check(valence, words_and_emoticons, start_i, i):
# --> 402         words_and_emoticons_lower = [str(w).lower() for w in words_and_emoticons]
#     403         if start_i == 0:
#     404             if negated([words_and_emoticons_lower[i - (start_i + 1)]]):  # 1 word preceding lexicon word (w/o stopwords)
#
# KeyboardInterrupt:

# %%
z = merged[:]

# %%
merged.shape
# Out:
# (2847, 17)

# %%
z = z.copy()
z["negative"] = z["text"].apply(lambda x: analyzer.polarity_scores(x)["neg"])

# %%
z["positive"] = z["text"].apply(lambda x: analyzer.polarity_scores(x)["pos"])

# %%
z["compound"] = z["text"].apply(lambda x: analyzer.polarity_scores(x)["compound"])

# %%
z["negative"]
# Out:
# 0       0.000
# 1       0.140
# 2       0.000
# 3       0.000
# 4       0.195
#         ...
# 2842    0.062
# 2843    0.000
# 2844    0.000
# 2845    0.000
# 2846    0.000
# Name: negative, Length: 2847, dtype: float64

# %%
z["cumulative_confirmed_smooth"] = z["cumulative_confirmed"].rolling(window=1000).mean()  # Adjust window size
plt.plot(z["negative"], z["cumulative_confirmed_smooth"])

# %%
z['interval'] = (z.index // 1000) # Aggregate every 1000 rows
z_agg = z.groupby('interval')[["negative","cumulative_confirmed","positive","compound"]].mean()
plt.plot(z_agg["negative"], z_agg["cumulative_confirmed"],color="r")
plt.plot(z_agg["positive"], z_agg["cumulative_confirmed"],color="y")
plt.plot(z_agg["compound"], z_agg["cumulative_confirmed"],color="g")

# %%
sns.kdeplot(z["negative"])
# Out:
# <Axes: xlabel='negative', ylabel='Density'>

# %%
sns.kdeplot(z["positive"])
# Out:
# <Axes: xlabel='positive', ylabel='Density'>

# %%
sns.kdeplot(z["compound"])
# Out:
# <Axes: xlabel='compound', ylabel='Density'>

# %%
plt.plot(z_agg.index ,z_agg["negative"],color="r")
plt.plot(z_agg.index ,z_agg["positive"],color="g")
plt.plot(z_agg.index ,z_agg["compound"],color='b')

# %%
z_agg.index
# Out:
# Index([0, 1, 2], dtype='int64', name='interval')

# %%
plt.plot(z_agg.index ,z_agg["positive"])

# %%
# 1. no of tweets datewise peak
# 2.find unigrarms , bigrams ,trigrams repeating
#3. analysis about specific covid vaccine timeseries

# %% [raw]
# DATA CLEANING

# %%
df["text"] = df["text"].str.lower()

# %%
df["text"]
# Out:
# 0        same folks said daikon paste could treat a cyt...
# 1        while the world has been on the wrong side of ...
# 2        #coronavirus #sputnikv #astrazeneca #pfizerbio...
# 3        facts are immutable, senator, even when you're...
# 4        explain to me again why we need a vaccine @bor...
#                                ...
# 31107    #15mar| “unexpected bet: europe negotiates #sp...
# 31108    dr reddy’s completes #russia's sputnik vaccine...
# 31109    @xsovietnews russia's #sputnikv vaccine is vas...
# 31110    the eu intends to start negotiations on the pu...
# 31111    #astrazaneca \n#vactine \n#sputnikv \n\nplease...
# Name: text, Length: 31112, dtype: object

# %%
df["text"]= df["text"].str.replace(r"http\S+","",regex=True)
df["text"] =  df["text"].str.replace(r"@\w+","",regex=True)
df["text"]  = df["text"].str.replace(r"\s{2,}", " ", regex=True)

# %%
df["text"]
# Out:
# 0        same folks said daikon paste could treat a cyt...
# 1        while the world has been on the wrong side of ...
# 2        #coronavirus #sputnikv #astrazeneca #pfizerbio...
# 3        facts are immutable, senator, even when you're...
# 4        explain to me again why we need a vaccine #whe...
#                                ...
# 31107    #15mar| “unexpected bet: europe negotiates #sp...
# 31108    dr reddy’s completes #russia's sputnik vaccine...
# 31109     russia's #sputnikv vaccine is vastly superior...
# 31110    the eu intends to start negotiations on the pu...
# 31111    #astrazaneca #vactine #sputnikv please give me...
# Name: text, Length: 31112, dtype: object

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots
from sklearn.feature_extraction.text import CountVectorizer

# %%
# prompt: change the ngram_df funciton and use simple matplotlib sns instead of plotly

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as stopwords
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# import plotly.express as px
# import plotly.graph_objects as go
# import plotly.figure_factory as ff
# from plotly.colors import n_colors
# from plotly.subplots import make_subplots
from sklearn.feature_extraction.text import CountVectorizer

df = pd.read_csv("vaccination_all_tweets.csv")
df.head()
df.sort_values(by="retweets").tail()
x = df[df["retweets"] > 12000]["text"]
print(x)
# !pip install vaderSentiment

analyzer = SentimentIntensityAnalyzer()
text = "I AM VERY SAD"
sentiment_scores = analyzer.polarity_scores(text)
print(sentiment_scores)

df2 = pd.read_csv("India_aggregate.csv")
df2.head()
y = df2.groupby("date")["cumulative_confirmed"].sum()
df3 = pd.DataFrame(y.reset_index())
df3["date"] = pd.to_datetime(df3["date"]).dt.date
df["date"]
type(df["date"][0])
df["date"] = pd.to_datetime(df["date"]).dt.date
df["date"]
df4 = df[df["user_location"].str.contains("India", na=False)]

merged = pd.merge(df3, df4, on="date")
merged
# plt.plot(merged["cumulative_confirmed"],analyzer.polarity_scores(merged["text"])["neg"])
z = merged[:]
merged.shape
z = z.copy()
z["negative"] = z["text"].apply(lambda x: analyzer.polarity_scores(x)["neg"])

z["positive"] = z["text"].apply(lambda x: analyzer.polarity_scores(x)["pos"])
z["compound"] = z["text"].apply(lambda x: analyzer.polarity_scores(x)["compound"])
z["negative"]
z["cumulative_confirmed_smooth"] = z["cumulative_confirmed"].rolling(
    window=1000).mean()  # Adjust window size
# plt.plot(z["negative"], z["cumulative_confirmed_smooth"])
z['interval'] = (z.index // 1000)  # Aggregate every 1000 rows
z_agg = z.groupby('interval')[
    ["negative", "cumulative_confirmed", "positive", "compound"]].mean()
# plt.plot(z_agg["negative"], z_agg["cumulative_confirmed"],color="r")
# plt.plot(z_agg["positive"], z_agg["cumulative_confirmed"],color="y")
# plt.plot(z_agg["compound"], z_agg["cumulative_confirmed"],color="g")
# sns.kdeplot(z["negative"])
# sns.kdeplot(z["positive"])
# sns.kdeplot(z["compound"])
# plt.plot(z_agg.index ,z_agg["negative"],color="r")
# plt.plot(z_agg.index ,z_agg["positive"],color="g")
# plt.plot(z_agg.index ,z_agg["compound"],color='b')
z_agg.index
# plt.plot(z_agg.index ,z_agg["positive"])


def ngram_df(df, n):
  """
  This function computes and plots the n-gram frequencies
  for a DataFrame of text data.
  """
  vectorizer = CountVectorizer(ngram_range=(n, n), stop_words=stopwords)
  X = vectorizer.fit_transform(df['text'])
  counts = pd.DataFrame(
      X.sum(axis=0),
      columns=['count']
  ).transpose()

  counts.columns = vectorizer.get_feature_names_out()
  counts = counts.transpose().sort_values('count', ascending=False)

  # Plotting the n-gram frequencies using matplotlib
  plt.figure(figsize=(10, 6))
  sns.barplot(x='count', y=counts.index, data=counts.reset_index(),
              orient='h', order=counts.index[:20])
  plt.title(f'Top 20 {n}-grams')
  plt.xlabel('Frequency')
  plt.ylabel(f'{n}-grams')
  plt.show()

# 1. no of tweets datewise peak
# 2.find unigrarms , bigrams ,trigrams repeating
# 3. analysis about specific covid vaccine timeseries
df["text"] = df["text"].str.lower()
df["text"]
df["text"] = df["text"].str.replace(r"http\S+", "", regex=True)
df["text"] = df["text"].str.replace(r"@\w+", "", regex=True)
df["text"] = df["text"].str.replace(r"\s{2,}", " ", regex=True)
df["text"]

ngram_df(df, 1)  # Unigrams
ngram_df(df, 2)  # Bigrams
ngram_df(df, 3)  # Trigrams
# Out:
# 221427    This video fits the last almost 2 years into 2...
# Name: text, dtype: object
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.8.30)
# {'neg': 0.531, 'neu': 0.469, 'pos': 0.0, 'compound': -0.5256}
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-50-1b17ffc46c12> in <cell line: 103>()
#     101 df["text"]
#     102
# --> 103 ngram_df(df, 1)  # Unigrams
#     104 ngram_df(df, 2)  # Bigrams
#     105 ngram_df(df, 3)  # Trigrams
#
# <ipython-input-50-1b17ffc46c12> in ngram_df(df, n)
#      73   """
#      74   vectorizer = CountVectorizer(ngram_range=(n, n), stop_words=stopwords)
# ---> 75   X = vectorizer.fit_transform(df['text'])
#      76   counts = pd.DataFrame(
#      77       X.sum(axis=0),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1464
#    1465             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466                 estimator._validate_params()
#    1467
#    1468             with config_context(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_params(self)
#     664         accepted constraints.
#     665         """
# --> 666         validate_parameter_constraints(
#     667             self._parameter_constraints,
#     668             self.get_params(deep=False),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      93                 )
#      94
# ---> 95             raise InvalidParameterError(
#      96                 f"The {param_name!r} parameter of {caller_name} must be"
#      97                 f" {constraints_str}. Got {param_val!r} instead."
#
# InvalidParameterError: The 'stop_words' parameter of CountVectorizer must be a str among {'english'}, an instance of 'list' or None. Got {'upon', 'name', 'thereafter', 'whereby', '‘s', 'where', 'him', 'about', 'too', 'onto', 'after', 'except', "'m", 'amongst', 're', 'been', 'some', 'alone', 'not', 'you', 'does', 'otherwise', 'as', 'whereafter', 'along', 'keep', 'under', 'show', 'something', 'namely', 'say', 'become', 'either', 'move', '’ll', 'again', 'four', 'its', 'side', 'often', 'same', 'go', '’s', 'further', 'ten', 'whereupon', 'formerly', 'seem', 'full', 'became', '’m', 'yourself', 'there', 'per', 'itself', 'they', '‘re', 'both', 'until', 'were', 'each', 'whenever', 'thus', 'them', 'yourselves', 'nothing', 'wherever', 'noone', 'on', 'back', 'doing', "'d", 'various', 'whoever', 'first', 'call', 'eight', 'wherein', 'toward', 'via', 'whatever', 'less', 'nor', 'top', 'hereafter', 'who', 'next', 'beyond', 'due', 'everywhere', 'many', 'are', 'whether', 'out', 'last', 'whereas', 'i', 'beforehand', 'have', 'how', 'must', 'indeed', 'other', 'since', 'also', 'had', 'us', 'me', 'no', 'third', 'with', '’re', 'anyway', 'it', 'though', '’d', 'moreover', 'the', 'hereby', 'is', 'ours', 'anyone', 'empty', 'nine', 'much', 'n’t', 'thence', 'take', 'nobody', 'bottom', 'am', 'from', 'would', 'former', 'sometimes', 'can', 'should', 'could', 'being', 'during', 'however', 'else', 'did', '‘ll', 'towards', "'re", 'herein', 'somewhere', 'perhaps', 'done', 'besides', 'this', 'please',...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

# Define the ngram_df function
def ngram_df(corpus, nrange, n=None):
    vec = CountVectorizer(stop_words='english', ngram_range=nrange).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    total_list = words_freq[:n]
    x = pd.DataFrame(total_list, columns=['text', 'count'])
    return x

# Generate n-gram DataFrames
unigram_df = ngram_df(df['text'], (1, 1), 20)
bigram_df = ngram_df(df['text'], (2, 2), 20)
trigram_df = ngram_df(df['text'], (3, 3), 20)

# Set up the matplotlib figure
plt.figure(figsize=(10, 18))

# Plot Unigrams
plt.subplot(3, 1, 1)
sns.barplot(y=unigram_df['text'][::-1], x=unigram_df['count'][::-1], palette='Blues_d')
plt.title('Top Unigrams')
plt.xlabel('Count')
plt.ylabel('Unigram')

# Plot Bigrams
plt.subplot(3, 1, 2)
sns.barplot(y=bigram_df['text'][::-1], x=bigram_df['count'][::-1], palette='Blues_d')
plt.title('Top Bigrams')
plt.xlabel('Count')
plt.ylabel('Bigram')

# Plot Trigrams
plt.subplot(3, 1, 3)
sns.barplot(y=trigram_df['text'][::-1], x=trigram_df['count'][::-1], palette='Blues_d')
plt.title('Top Trigrams')
plt.xlabel('Count')
plt.ylabel('Trigram')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-51-9b96eb35ad07>:27: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-51-9b96eb35ad07>:34: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-51-9b96eb35ad07>:41: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
df.columns
# Out:
# Index(['id', 'user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'retweets', 'favorites',
#        'is_retweet'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

# Define the ngram_df function without removing stopwords
def ngram_df(corpus, nrange, n=None):
    # Set stop_words to None to include all words
    vec = CountVectorizer(stop_words=None, ngram_range=nrange).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    total_list = words_freq[:n]
    x = pd.DataFrame(total_list, columns=['text', 'count'])
    return x

# Generate n-gram DataFrames
unigram_df = ngram_df(df['text'], (1, 1), 20)
bigram_df = ngram_df(df['text'], (2, 2), 20)
trigram_df = ngram_df(df['text'], (3, 3), 20)

# Set up the matplotlib figure
plt.figure(figsize=(10, 18))

# Plot Unigrams
plt.subplot(3, 1, 1)
sns.barplot(y=unigram_df['text'][::-1], x=unigram_df['count'][::-1], palette='Blues_d')
plt.title('Top Unigrams')
plt.xlabel('Count')
plt.ylabel('Unigram')

# Plot Bigrams
plt.subplot(3, 1, 2)
sns.barplot(y=bigram_df['text'][::-1], x=bigram_df['count'][::-1], palette='Blues_d')
plt.title('Top Bigrams')
plt.xlabel('Count')
plt.ylabel('Bigram')

# Plot Trigrams
plt.subplot(3, 1, 3)
sns.barplot(y=trigram_df['text'][::-1], x=trigram_df['count'][::-1], palette='Blues_d')
plt.title('Top Trigrams')
plt.xlabel('Count')
plt.ylabel('Trigram')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-52-227f923589cf>:31: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-52-227f923589cf>:38: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-52-227f923589cf>:45: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
df.columns
# Out:
# Index(['id', 'user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'retweets', 'favorites',
#        'is_retweet'],
#       dtype='object')

# %%
type(df["date"][0])
# Out:
# datetime.date

# %%
z = df["date"].value_counts()

# %%
type(z)
# Out:
# pandas.core.series.Series

# %%
dfdate = pd.DataFrame(z.index ,z.values)

# %%
dfdate
# Out:
#             date
# 2911  2021-03-01
# 2626  2021-06-29
# 2482  2021-07-19
# 2423  2021-04-21
# 2414  2021-06-30
# ...          ...
# 40    2020-12-25
# 39    2021-02-06
# 37    2021-02-03
# 31    2021-02-01
# 30    2021-01-31
#
# [319 rows x 1 columns]

# %%
# prompt: i want dfdate with columns , z.index , z.values , and index of dfdate should not be same as z.index

dfdate = pd.DataFrame({'z.index': z.index, 'z.values': z.values})
dfdate.index = range(1, len(dfdate) + 1)  # Set a new index different from z.index
dfdate.sort_values
# Out:
# <bound method DataFrame.sort_values of         z.index  z.values
# 1    2021-03-01      2911
# 2    2021-06-29      2626
# 3    2021-07-19      2482
# 4    2021-04-21      2423
# 5    2021-06-30      2414
# ..          ...       ...
# 315  2020-12-25        40
# 316  2021-02-06        39
# 317  2021-02-03        37
# 318  2021-02-01        31
# 319  2021-01-31        30
#
# [319 rows x 2 columns]>

# %%
plt.plot(dfdate["z.index"],dfdate["z.values"])

# %%
dfdate.sort_values(by="z.index",inplace=True)
plt.plot(dfdate["z.index"],dfdate["z.values"])

# %%
import pandas as pd
from scipy.signal import find_peaks

# Assuming 'dfdate' is your DataFrame and 'z.index' is the date column, 'z.values' is the tweet count column.
# Make sure dates are in datetime format
dfdate['z.index'] = pd.to_datetime(dfdate['z.index'])
dfdate.sort_values(by="z.index", inplace=True)

# Find peaks with a height threshold to filter out minor peaks
peaks, _ = find_peaks(dfdate["z.values"], height=750)  # Adjust 'height' as needed

# Extract peak dates and tweet counts
peak_dates = dfdate["z.index"].iloc[peaks]
peak_values = dfdate["z.values"].iloc[peaks]

# Display the peak dates and tweet counts
peak_info = pd.DataFrame({"Date": peak_dates, "Tweet Count": peak_values})
print(peak_info)
# Out:
#           Date  Tweet Count
# 1   2021-03-01         2911
# 38  2021-03-03         1349
# 90  2021-03-11          911
# 33  2021-03-16         1415
# 76  2021-03-20          995
# 89  2021-03-22          919
# 94  2021-03-24          874
# 46  2021-03-31         1259
# 109 2021-04-03          809
# 14  2021-04-08         1981
# 10  2021-04-12         2049
# 64  2021-04-19         1086
# 4   2021-04-21         2423
# 36  2021-05-14         1374
# 47  2021-05-16         1240
# 61  2021-05-20         1097
# 32  2021-05-25         1418
# 50  2021-05-28         1216
# 65  2021-06-01         1083
# 20  2021-06-08         1739
# 24  2021-06-11         1559
# 21  2021-06-17         1662
# 7   2021-06-23         2225
# 12  2021-06-25         2024
# 2   2021-06-29         2626
# 17  2021-07-13         1797
# 16  2021-07-16         1802
# 3   2021-07-19         2482
# 6   2021-07-23         2372
# 41  2021-07-28         1309
# 34  2021-07-30         1411
# 35  2021-08-02         1410
# 49  2021-08-05         1228
# 19  2021-08-11         1748
# 18  2021-08-13         1771
# 101 2021-08-18          847
# 52  2021-08-23         1196
# 71  2021-08-26         1021
# 121 2021-08-30          771
# 83  2021-09-01          957
# 95  2021-09-13          864
# 104 2021-09-17          844
# 110 2021-09-29          805
# 11  2021-10-12         2040
# 117 2021-10-14          780
# 113 2021-10-18          801
# 60  2021-10-21         1098
# 8   2021-11-03         2160
# 107 2021-11-09          826
# 115 2021-11-12          785
# 102 2021-11-19          846

# %%
dfdate["z.values"].mean()
# Out:
# 715.3824451410659

# %%
peak_info["Date"] = pd.to_datetime(peak_info["Date"]).dt.date
# Out:
# [datetime.date(2021, 3, 1),
#  datetime.date(2021, 3, 3),
#  datetime.date(2021, 3, 11),
#  datetime.date(2021, 3, 16),
#  datetime.date(2021, 3, 20),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 24),
#  datetime.date(2021, 3, 31),
#  datetime.date(2021, 4, 3),
#  datetime.date(2021, 4, 8),
#  datetime.date(2021, 4, 12),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 21),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 16),
#  datetime.date(2021, 5, 20),
#  datetime.date(2021, 5, 25),
#  datetime.date(2021, 5, 28),
#  datetime.date(2021, 6, 1),
#  datetime.date(2021, 6, 8),
#  datetime.date(2021, 6, 11),
#  datetime.date(2021, 6, 17),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 25),
#  datetime.date(2021, 6, 29),
#  datetime.date(2021, 7, 13),
#  datetime.date(2021, 7, 16),
#  datetime.date(2021, 7, 19),
#  datetime.date(2021, 7, 23),
#  datetime.date(2021, 7, 28),
#  datetime.date(2021, 7, 30),
#  datetime.date(2021, 8, 2),
#  datetime.date(2021, 8, 5),
#  datetime.date(2021, 8, 11),
#  datetime.date(2021, 8, 13),
#  datetime.date(2021, 8, 18),
#  datetime.date(2021, 8, 23),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 30),
#  datetime.date(2021, 9, 1),
#  datetime.date(2021, 9, 13),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 29),
#  datetime.date(2021, 10, 12),
#  datetime.date(2021, 10, 14),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 21),
#  datetime.date(2021, 11, 3),
#  datetime.date(2021, 11, 9),
#  datetime.date(2021, 11, 12),
#  datetime.date(2021, 11, 19)]

# %%
# Out:
# Fetching news for 2021-03-01: https://newsapi.org/v2/everything?q=COVID-19&from=2021-03-01&to=2021-03-01&language=en&sortBy=relevancy&pageSize=5&apiKey=14ab518a94e1440396aba2f7b92b07af
# Upgrade required for 2021-03-01: {'status': 'error', 'code': 'parameterInvalid', 'message': 'You are trying to request results too far in the past. Your plan permits you to request articles as far back as 2024-10-02, but you have requested 2021-03-01. You may need to upgrade to a paid plan.'}
# Fetching news for 2021-03-03: https://newsapi.org/v2/everything?q=COVID-19&from=2021-03-03&to=2021-03-03&language=en&sortBy=relevancy&pageSize=5&apiKey=14ab518a94e1440396aba2f7b92b07af
# Upgrade required for 2021-03-03: {'status': 'error', 'code': 'parameterInvalid', 'message': 'You are trying to request results too far in the past. Your plan permits you to request articles as far back as 2024-10-02, but you have requested 2021-03-03. You may need to upgrade to a paid plan.'}
# Fetching news for 2021-03-11: https://newsapi.org/v2/everything?q=COVID-19&from=2021-03-11&to=2021-03-11&language=en&sortBy=relevancy&pageSize=5&apiKey=14ab518a94e1440396aba2f7b92b07af
# Upgrade required for 2021-03-11: {'status': 'error', 'code': 'parameterInvalid', 'message': 'You are trying to request results too far in the past. Your plan permits you to request articles as far back as 2024-10-02, but you have requested 2021-03-11. You may need to upgrade to a paid plan.'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-2c1372b7a75d> in <cell line: 58>()
#      59     headlines = fetch_news(date, api_key)
#      60     news_data.append({'Date': date, 'Headlines': headlines})
# ---> 61     time.sleep(5)  # Add delay of 5 seconds between requests
#      62
#      63 # Convert to DataFrame and display results
#
# KeyboardInterrupt:

# %%
import time
import requests
import pandas as pd

# Your GNews API key
api_key = "e0d034505bebfd84c592babc4881165c" # Replace with your GNews API key

# List of peak dates
peak_dates = [
    "2021-03-01", "2021-03-03", "2021-03-11", "2021-03-16",
    "2021-03-20", "2021-03-22", "2021-03-24", "2021-03-31",
    "2021-04-03", "2021-04-08", "2021-04-12", "2021-04-19",
    "2021-04-21", "2021-05-14", "2021-05-16", "2021-05-20",
    "2021-05-25", "2021-05-28", "2021-06-01", "2021-06-08",
    "2021-06-11", "2021-06-17", "2021-06-23", "2021-06-25",
    "2021-06-29", "2021-07-13", "2021-07-16", "2021-07-19",
    "2021-07-23", "2021-07-28", "2021-07-30", "2021-08-02",
    "2021-08-05", "2021-08-11", "2021-08-13", "2021-08-18",
    "2021-08-23", "2021-08-26", "2021-08-30", "2021-09-01",
    "2021-09-13", "2021-09-17", "2021-09-29", "2021-10-12",
    "2021-10-14", "2021-10-18", "2021-10-21", "2021-11-03",
    "2021-11-09", "2021-11-12", "2021-11-19"
]

# Function to get news headlines for a specific date
def fetch_gnews(date, api_key):
    url = f'https://gnews.io/api/v4/search'
    params = {
        'q': 'COVID-19',  # You can customize this query
        'from': date,
        'to': date,
        'token': api_key,
        'lang': 'en',
        'max': 5  # Limit to 5 articles per date
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        articles = response.json().get('articles')
        headlines = [article['title'] for article in articles]
        return headlines
    else:
        print(f"Failed to fetch news for {date}: {response.status_code}")
        return []

# Fetch and store headlines for each peak date
news_data = []
for date in peak_dates:
    headlines = fetch_gnews(date, api_key)
    news_data.append({'Date': date, 'Headlines': headlines})
    time.sleep(5)  # Add delay of 5 seconds between requests

# Convert to DataFrame and display results
news_df = pd.DataFrame(news_data)
print(news_df)

# Optional: Save to CSV
news_df.to_csv('peak_date_news_headlines.csv', index=False)
# Out:
# Failed to fetch news for 2021-03-01: 403
# Failed to fetch news for 2021-03-03: 403
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-277c21223656> in <cell line: 47>()
#      48     headlines = fetch_gnews(date, api_key)
#      49     news_data.append({'Date': date, 'Headlines': headlines})
# ---> 50     time.sleep(5)  # Add delay of 5 seconds between requests
#      51
#      52 # Convert to DataFrame and display results
#
# KeyboardInterrupt:

# %%
import requests

def fetch_archive_news(query, date):
    url = f'https://archive.org/advancedsearch.php'
    params = {
        'q': query,
        'fl[]': 'title,description',
        'rows': 5,
        'start': 0,
        'output': 'json',
        'date': date
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        articles = response.json().get('response').get('docs')
        headlines = [article['title'] for article in articles]
        return headlines
    else:
        print(f"Failed to fetch news: {response.status_code} - {response.text}")
        return []

# Example usage
news_headlines = fetch_archive_news('COVID-19', '2021-03-01')  # Search for specific date
print(news_headlines)
# Out:
# Failed to fetch news: 400 - "<error>invalid value 2021-03-01 for request parameter date</error>"
#
# []

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=9106dc2978fd428c3b0696a5bd731466f5a1f9c16fe523da5230e70b5a030a1e
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.11 sgmllib3k-1.0.0
